# %%
import os.path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
# %matplotlib inline

# %%
awards = pd.read_csv('academy_awards.csv',  encoding='latin-1')

# %%
awards.head()
# Out:
#           Year               Category          Nominee  \
# 0  2010 (83rd)  Actor -- Leading Role    Javier Bardem
# 1  2010 (83rd)  Actor -- Leading Role     Jeff Bridges
# 2  2010 (83rd)  Actor -- Leading Role  Jesse Eisenberg
# 3  2010 (83rd)  Actor -- Leading Role      Colin Firth
# 4  2010 (83rd)  Actor -- Leading Role     James Franco
#
#                           Additional Info Won? Unnamed: 5 Unnamed: 6  \
# 0                      Biutiful {'Uxbal'}   NO        NaN        NaN
# 1           True Grit {'Rooster Cogburn'}   NO        NaN        NaN
# 2  The Social Network {'Mark Zuckerberg'}   NO        NaN        NaN
# 3    The King's Speech {'King George VI'}  YES        NaN        NaN
# 4              127 Hours {'Aron Ralston'}   NO        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN         NaN
# ...

# %%
awards.drop(['Unnamed: 5', 'Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10',], axis=1, inplace=True)

# %%
awards.rename(columns={'Won?': 'Winner','Additional Info': 'Movie'}, inplace=True)

# %%
awards.head()
# Out:
#           Year               Category          Nominee  \
# 0  2010 (83rd)  Actor -- Leading Role    Javier Bardem
# 1  2010 (83rd)  Actor -- Leading Role     Jeff Bridges
# 2  2010 (83rd)  Actor -- Leading Role  Jesse Eisenberg
# 3  2010 (83rd)  Actor -- Leading Role      Colin Firth
# 4  2010 (83rd)  Actor -- Leading Role     James Franco
#
#                                     Movie Winner
# 0                      Biutiful {'Uxbal'}     NO
# 1           True Grit {'Rooster Cogburn'}     NO
# 2  The Social Network {'Mark Zuckerberg'}     NO
# 3    The King's Speech {'King George VI'}    YES
# 4              127 Hours {'Aron Ralston'}     NO

# %%
awards.shape
# Out:
# (10137, 5)

# %%
Directing =  awards[awards.Category == 'Directing']
leadActor =  awards[awards.Category == 'Actor -- Leading Role']
leadActress =  awards[awards.Category == 'Actress -- Leading Role']
supportActor =  awards[awards.Category == 'Actor -- Supporting Role']
supportActress =  awards[awards.Category == 'Actress -- Supporting Role']
editing =  awards[awards.Category == 'Film Editing']

# %%
leadActor.head()
# Out:
#           Year               Category          Nominee  \
# 0  2010 (83rd)  Actor -- Leading Role    Javier Bardem
# 1  2010 (83rd)  Actor -- Leading Role     Jeff Bridges
# 2  2010 (83rd)  Actor -- Leading Role  Jesse Eisenberg
# 3  2010 (83rd)  Actor -- Leading Role      Colin Firth
# 4  2010 (83rd)  Actor -- Leading Role     James Franco
#
#                                     Movie Winner
# 0                      Biutiful {'Uxbal'}     NO
# 1           True Grit {'Rooster Cogburn'}     NO
# 2  The Social Network {'Mark Zuckerberg'}     NO
# 3    The King's Speech {'King George VI'}    YES
# 4              127 Hours {'Aron Ralston'}     NO

# %%
#leadActor.dtypes
leadActor.Movie.str.split('{',expand =False)
#leadActor.Movie.str.split(pat='{', expand=True)
#data = leadActor
#leadActor = pd.read_table(io.StringIO(data), sep='  ')

# Reformat values for column a using an unnamed lambda function
#leadActor['Movie'] = leadActor['Movie'].apply(lambda x: x.split('{')[0])
# Out:
# 0                                    [Biutiful , 'Uxbal'}]
# 1                         [True Grit , 'Rooster Cogburn'}]
# 2                [The Social Network , 'Mark Zuckerberg'}]
# 3                  [The King's Speech , 'King George VI'}]
# 4                            [127 Hours , 'Aron Ralston'}]
# 135                           [Crazy Heart , 'Bad Blake'}]
# 136                      [Up in the Air , 'Ryan Bingham'}]
# 137                             [A Single Man , 'George'}]
# 138                         [Invictus , 'Nelson Mandela'}]
# 139      [The Hurt Locker , 'Staff Sergeant William Jam...
# 275                              [The Visitor , 'Walter'}]
# 276                       [Frost/Nixon , 'Richard Nixon'}]
# 277                                [Milk , 'Harvey Milk'}]
# 278      [The Curious Case of Benjamin Button , 'Benjam...
# 279                              [The Wrestler , 'Randy'}]
# 393                 [Michael Clayton , 'Michael Clayton'}]
# ...

# %%
merged = pd.concat([Directing,leadActor,leadActress,supportActor,supportActress,editing],axis=0,ignore_index=True)

# %%
merged.shape
# Out:
# (2364, 5)

# %%
awards.groupby('Year').count()
# Out:
#                Category  Nominee  Movie  Winner
# Year
# 1927/28 (1st)        39       39     29      39
# 1928/29 (2nd)        38       38     38      38
# 1929/30 (3rd)        42       42     42      42
# 1930/31 (4th)        50       50     40      50
# 1931/32 (5th)        47       47     40      47
# 1932/33 (6th)        65       65     44      65
# 1934 (7th)           68       68     63      68
# 1935 (8th)           95       95     78      95
# 1936 (9th)          115      115     98     115
# 1937 (10th)         135      135    113     135
# 1938 (11th)         145      145    126     145
# 1939 (12th)         153      153    137     153
# 1940 (13th)         162      162    158     162
# 1941 (14th)         192      192    177     192
# 1942 (15th)         190      190    182     190
# 1943 (16th)         188      188    180     188
# 1944 (17th)         181      181    165     181
# 1945 (18th)         163      163    157     163
# ...

# %%
merged.rename(columns={'Won?': 'Winner','Additional Info': 'Movie'}, inplace=True)

# %%
merged.head()
# Out:
#           Year   Category             Nominee                     Movie Winner
# 0  2010 (83rd)  Directing          Black Swan          Darren Aronofsky     NO
# 1  2010 (83rd)  Directing         The Fighter          David O. Russell     NO
# 2  2010 (83rd)  Directing   The King's Speech                Tom Hooper    YES
# 3  2010 (83rd)  Directing  The Social Network             David Fincher     NO
# 4  2010 (83rd)  Directing           True Grit  Joel Coen and Ethan Coen     NO

# %%
merged.shape
# Out:
# (2364, 5)

# %%
merged =  merged[merged.Winner == 'YES']

# %%
merged.head(10)
# Out:
#            Year   Category                                        Nominee  \
# 2   2010 (83rd)  Directing                              The King's Speech
# 6   2009 (82nd)  Directing                                The Hurt Locker
# 14  2008 (81st)  Directing                            Slumdog Millionaire
# 18  2007 (80th)  Directing                         No Country for Old Men
# 21  2006 (79th)  Directing                                   The Departed
# 25  2005 (78th)  Directing                             Brokeback Mountain
# 31  2004 (77th)  Directing                            Million Dollar Baby
# 36  2003 (76th)  Directing  The Lord of the Rings: The Return of the King
# 43  2002 (75th)  Directing                                    The Pianist
# 45  2001 (74th)  Directing                               A Beautiful Mind
#
#                        Movie Winner
# 2                 Tom Hooper    YES
# 6            Kathryn Bigelow    YES
# 14               Danny Boyle    YES
# ...

# %%
merged.shape
# Out:
# (481, 5)

# %%
merged.groupby('Category').head()
# Out:
#              Year                    Category                 Nominee  \
# 2     2010 (83rd)                   Directing       The King's Speech
# 6     2009 (82nd)                   Directing         The Hurt Locker
# 14    2008 (81st)                   Directing     Slumdog Millionaire
# 18    2007 (80th)                   Directing  No Country for Old Men
# 21    2006 (79th)                   Directing            The Departed
# 413   2010 (83rd)       Actor -- Leading Role             Colin Firth
# 415   2009 (82nd)       Actor -- Leading Role            Jeff Bridges
# 422   2008 (81st)       Actor -- Leading Role               Sean Penn
# 426   2007 (80th)       Actor -- Leading Role        Daniel Day-Lewis
# 434   2006 (79th)       Actor -- Leading Role         Forest Whitaker
# 821   2010 (83rd)     Actress -- Leading Role         Natalie Portman
# 823   2009 (82nd)     Actress -- Leading Role          Sandra Bullock
# ...

# %%
Director_idx = (merged['Category'] == 'Directing')
merged.loc[Director_idx,['Nominee','Movie']] = merged.loc[Director_idx,['Movie','Nominee']].values

# %%
merged.groupby('Category').head()
# Out:
#              Year                    Category                   Nominee  \
# 2     2010 (83rd)                   Directing                Tom Hooper
# 6     2009 (82nd)                   Directing           Kathryn Bigelow
# 14    2008 (81st)                   Directing               Danny Boyle
# 18    2007 (80th)                   Directing  Joel Coen and Ethan Coen
# 21    2006 (79th)                   Directing           Martin Scorsese
# 413   2010 (83rd)       Actor -- Leading Role               Colin Firth
# 415   2009 (82nd)       Actor -- Leading Role              Jeff Bridges
# 422   2008 (81st)       Actor -- Leading Role                 Sean Penn
# 426   2007 (80th)       Actor -- Leading Role          Daniel Day-Lewis
# 434   2006 (79th)       Actor -- Leading Role           Forest Whitaker
# 821   2010 (83rd)     Actress -- Leading Role           Natalie Portman
# 823   2009 (82nd)     Actress -- Leading Role            Sandra Bullock
# ...

# %%
Editor_idx = (merged['Category'] == 'Film Editing')
merged.loc[Editor_idx ,['Nominee','Movie']] = merged.loc[Editor_idx ,['Movie','Nominee']].values

# %%
merged.groupby('Category').head()
# Out:
#              Year                    Category                       Nominee  \
# 2     2010 (83rd)                   Directing                    Tom Hooper
# 6     2009 (82nd)                   Directing               Kathryn Bigelow
# 14    2008 (81st)                   Directing                   Danny Boyle
# 18    2007 (80th)                   Directing      Joel Coen and Ethan Coen
# 21    2006 (79th)                   Directing               Martin Scorsese
# 413   2010 (83rd)       Actor -- Leading Role                   Colin Firth
# 415   2009 (82nd)       Actor -- Leading Role                  Jeff Bridges
# 422   2008 (81st)       Actor -- Leading Role                     Sean Penn
# 426   2007 (80th)       Actor -- Leading Role              Daniel Day-Lewis
# 434   2006 (79th)       Actor -- Leading Role               Forest Whitaker
# 821   2010 (83rd)     Actress -- Leading Role               Natalie Portman
# ...

# %%
merged['Movie'] = merged['Movie'].str.split(pat='{')

# %%
merged.groupby('Category').head()
# Out:
#              Year                    Category                       Nominee  \
# 2     2010 (83rd)                   Directing                    Tom Hooper
# 6     2009 (82nd)                   Directing               Kathryn Bigelow
# 14    2008 (81st)                   Directing                   Danny Boyle
# 18    2007 (80th)                   Directing      Joel Coen and Ethan Coen
# 21    2006 (79th)                   Directing               Martin Scorsese
# 413   2010 (83rd)       Actor -- Leading Role                   Colin Firth
# 415   2009 (82nd)       Actor -- Leading Role                  Jeff Bridges
# 422   2008 (81st)       Actor -- Leading Role                     Sean Penn
# 426   2007 (80th)       Actor -- Leading Role              Daniel Day-Lewis
# 434   2006 (79th)       Actor -- Leading Role               Forest Whitaker
# 821   2010 (83rd)     Actress -- Leading Role               Natalie Portman
# ...

# %%
merged['Movie'] = merged['Movie'].replace(to_replace='{}', value='')

# %%
merged.groupby('Category').head()
# Out:
#              Year                    Category                       Nominee  \
# 2     2010 (83rd)                   Directing                    Tom Hooper
# 6     2009 (82nd)                   Directing               Kathryn Bigelow
# 14    2008 (81st)                   Directing                   Danny Boyle
# 18    2007 (80th)                   Directing      Joel Coen and Ethan Coen
# 21    2006 (79th)                   Directing               Martin Scorsese
# 413   2010 (83rd)       Actor -- Leading Role                   Colin Firth
# 415   2009 (82nd)       Actor -- Leading Role                  Jeff Bridges
# 422   2008 (81st)       Actor -- Leading Role                     Sean Penn
# 426   2007 (80th)       Actor -- Leading Role              Daniel Day-Lewis
# 434   2006 (79th)       Actor -- Leading Role               Forest Whitaker
# 821   2010 (83rd)     Actress -- Leading Role               Natalie Portman
# ...
